# %%
reason = dbutils.jobs.taskValues.get(taskKey="check_new_data", key="reason", default="unknown")
row_count = dbutils.jobs.taskValues.get(taskKey="check_new_data", key="current_training_row_count", default="0")
gold_version = dbutils.jobs.taskValues.get(taskKey="check_new_data", key="current_gold_version", default="-1")
print(f"SKIP: reason={reason} current_row_count={row_count} current_gold_version={gold_version}")
